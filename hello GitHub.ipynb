# %% [markdown]
# This notebook will be used for capstone project

# %%
# !pip install pandas as pd
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.6/site-packages (1.0.3)
# Collecting as
#   Downloading as-0.1-py3-none-any.whl (2.2 kB)
# Collecting pd
#   Downloading pd-0.0.1.tar.gz (5.3 kB)
# Requirement already satisfied: numpy>=1.13.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Building wheels for collected packages: pd
#   Building wheel for pd (setup.py) ... done
#   Created wheel for pd: filename=pd-0.0.1-py3-none-any.whl size=6505 sha256=d2818e1ed5d467ff0f8ffd0ea68544c92b0214f090e748e69696b66d61441fc3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a8/ce/4f/169c9ec9edbd0d04637602bb716fb543d16bb76c04a4e06296
# Successfully built pd
# Installing collected packages: as, pd
# Successfully installed as-0.1 pd-0.0.1

# %%
# !pip install Numpy as np
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: Numpy in /srv/conda/envs/notebook/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: as in /srv/conda/envs/notebook/lib/python3.6/site-packages (0.1)
# Collecting np
#   Downloading np-1.0.2.tar.gz (7.4 kB)
# Building wheels for collected packages: np
#   Building wheel for np (setup.py) ... done
#   Created wheel for np: filename=np-1.0.2-py3-none-any.whl size=13652 sha256=4a75445a78332ccf0c3c16e8a4051a74d8f90653ff84af631bf75d21eb71f9d3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2a/a4/f6/9c61fc4de0a7ad2232f00c2c87c407b52f61079467924f1c38
# Successfully built np
# Installing collected packages: np
# Successfully installed np-1.0.2

# %%
print(" Hello Capstone Project Course!")
# Out:
#  Hello Capstone Project Course!

# %%
# Out:
#   File "<ipython-input-10-4d6012b15ea2>", line 1
#     install pandas as pd
#                  ^
# SyntaxError: invalid syntax
